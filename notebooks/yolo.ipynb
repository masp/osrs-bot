# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
# model = YOLO('yolov8n.yaml')

# Load a pretrained YOLO model (recommended for training)
model = YOLO('../models/best_willows.pt')

# Train the model using the 'coco128.yaml' dataset for 3 epochs
# results = model.train(data='coco128.yaml', epochs=3)

# Evaluate the model's performance on the validation set
# results = model.val()

# Perform object detection on an image using the model

# Export the model to ONNX format
# success = model.export(format='onnx')

# %%
import cv2
from matplotlib import pyplot as plt

# %%
res = model("../snapshots/high_angle.png")
res_plotted = res[0].plot()

# Graph res_plotted as image
plt.imshow(cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# image 1/1 /Users/markasp/Documents/osrs-bot/notebooks/../snapshots/high_angle.png: 416x640 1 person, 16 trees, 147.0ms
# Speed: 3.2ms preprocess, 147.0ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
